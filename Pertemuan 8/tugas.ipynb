# %% [markdown]
# # TUGAS
#
# #### NAMA     : AHMED FATHIR SYAFAAT
# #### KELAS    : TI - 3H
# #### NIM      : 2241720083

# %% [markdown]
# Lakukan klasifikasi pada data MNIST dengan menggunakan model ANN
#
# Anda diperbolehkan melakukan eksplorasi terhadap,
#
# - Metode pra pengolahan
# - Pemilihan fitur
# - Arsitektur ANN
# - Fungsi Aktiviasi
#
# ANN diimplementasikan dengan menggunakan tensorflow.

# %%
# Import library yang diperlukan
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.utils import to_categorical

# %%
# Load Dataset
print("Loading MNIST dataset...")
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Loading MNIST dataset...

# %%
# Pra-pengolahan Data
def preprocess_data(X_train, X_test, y_train, y_test, use_pca=False, n_components=200):
    print("\nPra-pengolahan Data:")
    print("- Normalisasi")
    print("- Reshape")
    if use_pca:
        print("- PCA untuk reduksi dimensi")
    
    # Reshape data
    X_train = X_train.reshape(X_train.shape[0], 28*28)
    X_test = X_test.reshape(X_test.shape[0], 28*28)
    
    # Normalisasi menggunakan StandardScaler
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    # Opsi PCA untuk reduksi dimensi
    if use_pca:
        pca = PCA(n_components=n_components)
        X_train = pca.fit_transform(X_train)
        X_test = pca.transform(X_test)
        print(f"- Variance explained: {np.sum(pca.explained_variance_ratio_):.4f}")
    
    # One-hot encoding untuk label
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)
    
    return X_train, X_test, y_train, y_test

# %%
# Membuat Model ANN
def create_model(input_shape, activation='relu', architecture=[512, 256, 128]):
    print("\nArsitektur Model:")
    print(f"- Input shape: {input_shape}")
    print(f"- Hidden layers: {architecture}")
    print(f"- Activation function: {activation}")
    
    model = Sequential()
    
    # Input layer
    model.add(Dense(architecture[0], activation=activation, input_shape=input_shape))
    model.add(Dropout(0.3))
    
    # Hidden layers
    for units in architecture[1:]:
        model.add(Dense(units, activation=activation))
        model.add(Dropout(0.3))
    
    # Output layer
    model.add(Dense(10, activation='softmax'))
    
    return model

# %%
# Training dan Evaluasi
def train_and_evaluate(model, X_train, X_test, y_train, y_test):
    # Kompilasi model
    model.compile(optimizer='adam',
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])
    
    print("\nTraining Model...")
    # Training
    history = model.fit(X_train, y_train,
                        batch_size=128,
                        epochs=20,
                        validation_split=0.2,
                        verbose=1)
    
    # Evaluasi
    print("\nEvaluasi Model:")
    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"Test accuracy: {test_accuracy:.4f}")
    
    # Confusion Matrix
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np. argmax(y_test, axis=1)
    cm = confusion_matrix(y_test_classes, y_pred_classes)
    
    return test_accuracy, cm

# %%
# Visualisasi hasil
def plot_confusion_matrix(cm):
    plt.figure(figsize=(10,8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# %%
# Eksplorasi
use_pca = True
n_components = 200
input_shape = (n_components,) if use_pca else (784,)
X_train, X_test, y_train, y_test = preprocess_data(X_train, X_test, y_train, y_test, use_pca, n_components)
model = create_model(input_shape)
test_accuracy, cm = train_and_evaluate(model, X_train, X_test, y_train, y_test)
plot_confusion_matrix(cm)
# Out:
# Pra-pengolahan Data:
# - Normalisasi
# - Reshape
# - PCA untuk reduksi dimensi
# - Variance explained: 0.8661
#
# Arsitektur Model:
# - Input shape: (200,)
# - Hidden layers: [512, 256, 128]
# - Activation function: relu
# c:\Anaconda\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training Model...
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7269 - loss: 0.8885 - val_accuracy: 0.9473 - val_loss: 0.1802
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9263 - loss: 0.2623 - val_accuracy: 0.9612 - val_loss: 0.1396
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9455 - loss: 0.1883 - val_accuracy: 0.9653 - val_loss: 0.1228
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9548 - loss: 0.1580 - val_accuracy: 0.9686 - val_loss: 0.1174
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9614 - loss: 0.1344 - val_accuracy: 0.9694 - val_loss: 0.1112
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9642 - loss: 0.1277 - val_accuracy: 0.9712 - val_loss: 0.1089
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9694 - loss: 0.1042 - val_accuracy: 0.9733 - val_loss: 0.1043
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9708 - loss: 0.0973 - val_accuracy: 0.9745 - val_loss: 0.1021
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9734 - loss: 0.0890 - val_accuracy: 0.9750 - val_loss: 0.1017
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9761 - loss: 0.0834 - val_accuracy: 0.9747 - val_loss: 0.1033
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9785 - loss: 0.0735 - val_accuracy: 0.9756 - val_loss: 0.0990
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9791 - loss: 0.0718 - val_accuracy: 0.9748 - val_loss: 0.1089
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9800 - loss: 0.0673 - val_accuracy: 0.9766 - val_loss: 0.1048
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9806 - loss: 0.0665 - val_accuracy: 0.9760 - val_loss: 0.1114
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9814 - loss: 0.0612 - val_accuracy: 0.9768 - val_loss: 0.1058
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9818 - loss: 0.0602 - val_accuracy: 0.9777 - val_loss: 0.1032
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9833 - loss: 0.0565 - val_accuracy: 0.9759 - val_loss: 0.1104
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9830 - loss: 0.0595 - val_accuracy: 0.9753 - val_loss: 0.1193
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9840 - loss: 0.0554 - val_accuracy: 0.9769 - val_loss: 0.1232
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9857 - loss: 0.0509 - val_accuracy: 0.9759 - val_loss: 0.1225
#
# Evaluasi Model:
# Test accuracy: 0.9783
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
